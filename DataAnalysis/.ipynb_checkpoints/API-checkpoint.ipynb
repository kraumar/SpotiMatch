# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
def load_users_data(csv1, csv2):
    data1 = pd.read_csv(csv1)
    data2 = pd.read_csv(csv2)
    
    data1 = data1.dropna(subset=['name'])
    data2 = data2.dropna(subset=['name'])
    
    columns1 = [c for c in data1.columns if c.lower()[:6] != 'genres' and c.lower() != 'type' and c.lower() != 'popularity' and c.lower()[:9] != 'followers']
    columns2 = [c for c in data2.columns if c.lower()[:6] != 'genres' and c.lower() != 'type' and c.lower() != 'popularity' and c.lower()[:9] != 'followers']
    
    data1 = data1[columns1]
    data2 = data2[columns2]
    
    return data1, data2

# %%
data1, data2 = load_users_data("1.csv","1.csv")
# Out:
# ['external_urls__spotify', 'followers__href', 'followers__total', 'href', 'id', 'images__height', 'images__url', 'images__width', 'name', 'uri']

# %%
data1.head()
# Out:
#                                external_urls__spotify  followers__href  \
# 0   https://open.spotify.com/artist/6kBDZFXuLrZgHn...              NaN
# 3   https://open.spotify.com/artist/75xNYf2GU5wtQq...              NaN
# 6   https://open.spotify.com/artist/4SQdUpG4f7UbkJ...              NaN
# 9   https://open.spotify.com/artist/7Eu1txygG6nJtt...              NaN
# 12  https://open.spotify.com/artist/6nxWCVXbOlEVRe...              NaN
#
#     followers__total                                               href  \
# 0           633347.0  https://api.spotify.com/v1/artists/6kBDZFXuLrZ...
# 3            34636.0  https://api.spotify.com/v1/artists/75xNYf2GU5w...
# 6           150764.0  https://api.spotify.com/v1/artists/4SQdUpG4f7U...
# 9           470594.0  https://api.spotify.com/v1/artists/7Eu1txygG6n...
# 12         2068064.0  https://api.spotify.com/v1/artists/6nxWCVXbOlE...
#
#                         id  images__height  \
# 0   6kBDZFXuLrZgHnvmPu9NsG             640
# 3   75xNYf2GU5wtQqBrd74SlY             640
# 6   4SQdUpG4f7UbkJG3cJ2Iyj             640
# 9   7Eu1txygG6nJttLHbZdQOh             640
# 12  6nxWCVXbOlEVRexSbLsTer             640
#
#                                           images__url  images__width  \
# 0   https://i.scdn.co/image/5630c4ae80c6d8cb16f021...            640
# 3   https://i.scdn.co/image/584bb5aa6fe65794009e4a...            640
# 6   https://i.scdn.co/image/c56cf774b9ffa40e0af35f...            640
# 9   https://i.scdn.co/image/f96458025a0640bf1d3c8f...            640
# 12  https://i.scdn.co/image/0436e3871c9f88b8f83559...            640
#
#           name                                    uri
# 0   Aphex Twin  spotify:artist:6kBDZFXuLrZgHnvmPu9NsG
# 3       Zheani  spotify:artist:75xNYf2GU5wtQqBrd74SlY
# 6         Arca  spotify:artist:4SQdUpG4f7UbkJG3cJ2Iyj
# 9     Four Tet  spotify:artist:7Eu1txygG6nJttLHbZdQOh
# 12       Flume  spotify:artist:6nxWCVXbOlEVRexSbLsTer

# %%
data2.head()
# Out:
#                                external_urls__spotify  followers__href  \
# 0   https://open.spotify.com/artist/6kBDZFXuLrZgHn...              NaN
# 3   https://open.spotify.com/artist/75xNYf2GU5wtQq...              NaN
# 6   https://open.spotify.com/artist/4SQdUpG4f7UbkJ...              NaN
# 9   https://open.spotify.com/artist/7Eu1txygG6nJtt...              NaN
# 12  https://open.spotify.com/artist/6nxWCVXbOlEVRe...              NaN
#
#     followers__total                                               href  \
# 0           633347.0  https://api.spotify.com/v1/artists/6kBDZFXuLrZ...
# 3            34636.0  https://api.spotify.com/v1/artists/75xNYf2GU5w...
# 6           150764.0  https://api.spotify.com/v1/artists/4SQdUpG4f7U...
# 9           470594.0  https://api.spotify.com/v1/artists/7Eu1txygG6n...
# 12         2068064.0  https://api.spotify.com/v1/artists/6nxWCVXbOlE...
#
#                         id  images__height  \
# 0   6kBDZFXuLrZgHnvmPu9NsG             640
# 3   75xNYf2GU5wtQqBrd74SlY             640
# 6   4SQdUpG4f7UbkJG3cJ2Iyj             640
# 9   7Eu1txygG6nJttLHbZdQOh             640
# 12  6nxWCVXbOlEVRexSbLsTer             640
#
#                                           images__url  images__width  \
# 0   https://i.scdn.co/image/5630c4ae80c6d8cb16f021...            640
# 3   https://i.scdn.co/image/584bb5aa6fe65794009e4a...            640
# 6   https://i.scdn.co/image/c56cf774b9ffa40e0af35f...            640
# 9   https://i.scdn.co/image/f96458025a0640bf1d3c8f...            640
# 12  https://i.scdn.co/image/0436e3871c9f88b8f83559...            640
#
#           name                                    uri
# 0   Aphex Twin  spotify:artist:6kBDZFXuLrZgHnvmPu9NsG
# 3       Zheani  spotify:artist:75xNYf2GU5wtQqBrd74SlY
# 6         Arca  spotify:artist:4SQdUpG4f7UbkJG3cJ2Iyj
# 9     Four Tet  spotify:artist:7Eu1txygG6nJttLHbZdQOh
# 12       Flume  spotify:artist:6nxWCVXbOlEVRexSbLsTer
